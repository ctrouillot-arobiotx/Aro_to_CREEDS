# %%
import mysql.connector

import pandas as pd

 

#Connect to siDB and query oligos of interest

cnx = mysql.connector.connect(user='sanderson',

                              password=$PASSWORD

                              database='SIRNA',

                              host='localhost')

cursor = cnx.cursor()

 

#Read in database as pandas dataframe

df = pd.read_sql("SELECT * FROM target_transcripts ",

                             con=cnx)

 

#Update database with dataframe

#

 

#Iterate through df row by row

for index, row in df_db.iterrows():

 

       #Generate command where we set values

        sql = "REPLACE INTO target_mismatches SET \

        core_AS_sequence_id=" + str(row['row_id_coreseq']) + ", \

        target_transcript_id=" + str(row['row_id_tx']) + ", \

        total_mismatches=" + str(row['total_mismatches']) + ", \

        target_id=" + str(target_id) + ", \

        organism_id=" + str(row['row_id_org'])

             

              #run the command in mysql

        cursor.execute(sql)

              #Commit the changes to the database

        cnx.commit()
